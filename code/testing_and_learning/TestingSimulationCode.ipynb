# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science','notebook','grid'])

from datetime import datetime as dt

# %%
import importlib
from src import PhotonBoxPropagationSimulator as Simulator
from src import LinearAttenuationCoeff_load as LAC_loader

# %% [markdown]
# ---
# ## Linear Attenuation Coefficients

# %%
importlib.reload(LAC_loader)
# lac
fp_mac = "../mac_NistXcom/mac_lead.txt"
lead_density = 11.34 # g/cm^3
lac_loader = LAC_loader.LACLoader(fp_mac,lead_density,"Svinec")

# %% [markdown]
# ---
# ---
# # Simulation time

# %% [markdown]
# ### Parameters setup

# %%
# refesh module
importlib.reload(Simulator)
#* define parameters:
# box dimensions in HVL units
n_hvl_X = 6
# energy of incident photons
E0 = 1 # MeV
# side lengths - note: photons start in the middle, so they need to travel only half of the box length to reach the edge!
n_hvl_Y = 10
n_hvl_Z = 10

method_index = 4
simulation_method = ["simulate",  "buildup", "pdf", "forcing", "combined"] [method_index]            
Nsim = 100000

verbose = True
path_extension_factor = 2
force_first_interaction = True
weight_min = 0.01
survival_probability = 0.1

# ? want reproducible results? set the seed for the random number generator
#np.random.seed(1234355)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Configuration (passed as run() argument)

# %%
config = {
    "simulation_method": simulation_method,
    "Nsim": Nsim,
    "Srep_index": 0,
    "verbose": verbose,
    "progress_report_frequency": 10,
    "path_extension_factor": path_extension_factor,
    "force_first_interaction": force_first_interaction,
    "weight_min": weight_min,
    "start_weight": 1.0,
    "survival_probability": survival_probability
}

config
# Out:
# {'simulation_method': 'combined_altered',
#  'Nsim': 100000,
#  'Srep_index': 0,
#  'verbose': True,
#  'progress_report_frequency': 10,
#  'path_extension_factor': 2,
#  'force_first_interaction': True,
#  'weight_min': 0.01,
#  'start_weight': 1.0,
#  'survival_probability': 0.1}

# %% [markdown]
# ---
# ---
# ## Run simulation

# %%
#* initialize simulator class instance
simulator = Simulator.photon_box_propagation_simulator((n_hvl_X, n_hvl_Y, n_hvl_Z), lac_loader, E0)

#? want reproducible results? set the seed for the random number generator
#np.random.seed(1234355)

sim_info = simulator.run(config)
# Out:
# 	Progress: 10.00% (15.29 sec)
# 	Progress: 20.00% (29.38 sec)
# 	Progress: 30.00% (43.85 sec)
# 	Progress: 40.00% (60.17 sec)
# 	Progress: 50.00% (77.50 sec)
# 	Progress: 60.00% (95.94 sec)
# 	Progress: 70.00% (113.94 sec)
# 	Progress: 80.00% (127.77 sec)
# 	Progress: 90.00% (141.74 sec)

# %%
sim_info
# Out:
# {'method': 'combined_altered',
#  'E0': 1,
#  'n_hvl_x': 6,
#  'Srep_index': 0,
#  'simulation_time_sec': 155.506514,
#  'N_stps_per_Nsim': 3.85418,
#  'buildup_factor': 0.5752252278124609,
#  'n_hvl_y': 10,
#  'n_hvl_z': 10,
#  'Nsim': 100000,
#  'force_first_interaction': None,
#  'path_extension_factor': None,
#  'weight_min': None,
#  'survival_probability': None,
#  'N_out_total': 13692,
#  'E_out_total': 898.7894184569701,
#  'N_out_primaries': 0,
#  'E_out_primaries': 0.0,
#  'N_out_secondaries': 13692,
#  'E_out_secondaries': 898.7894184569701,
#  'N_backscattered': 1756,
#  'E_backscattered': 38.37849342690324,
#  'N_leakage': 204,
#  'E_leakage': 2.326614023495246,
#  'N_absorbed': 101070,
#  'E_absorbed': 101070,
#  'N_steps': 385418,
#  'N_stps_per_sec': 2478.4685225469075,
#  'Nsim_per_sec': 643.059878507726}

# %% [markdown]
# ---
# ---
# ## Simulation results reports
# - post_simulation_counting
# - report_and_save
#
# ***Those two should be changed, maybe united***

# %%
#simulator.post_simulation_counting(report=True)
#simulator.report_and_save(save_to_file=False,print_report=True)
# Out:
# ======================================================================
#                      SIMULATION COUNTING RESULTS
# ======================================================================
#
#                         SIMULATION / EXECUTION
# ----------------------------------------------------------------------
#   Simulation method:            buildup
#   Incident energy E0:           2.000000 MeV
#   Number of primary photons:    10000
#   Shield thickness:             4 HVL
#   Simulation time:              8.87 sec
#
#                             PHOTON COUNTS
# ----------------------------------------------------------------------
#   Total simulation steps:       26714
#   Successful steps:             26714
#   Total interactions:           25072
#   Compton interactions:         0
#   Photoeffect interactions:     0
#   Pair production interactions: 0
#
#                             EXITED PHOTONS
# ----------------------------------------------------------------------
#   Out total:                    1371
#   Out primaries:                638
#   Out secondaries:              733
#   Backscattered:                269
#   Leakage:                      2
#   Total exited photons:         1642
#
#                        PHOTONS ENDING IN SHIELD
# ----------------------------------------------------------------------
#   In box total:                 0
#   Absorbed:                     0
#   Weight terminated:            0
#   Energy terminated:            0
#   Total terminated:             0
#
#                           ENERGY ACCOUNTING
# ----------------------------------------------------------------------
#   E_out total:                  2236.432333 MeV
#   E_out primaries:              1276.000000 MeV
#   E_out secondaries:            960.432333 MeV
#   E_backscattered:              116.149267 MeV
#   E_leakage:                    1.179193 MeV
#   E_exit total:                 2353.760792 MeV
#   E_absorbed:                   0.000000 MeV
#   E_weight_terminated:          0.000000 MeV
#   E_energy_terminated:          0.000000 MeV
#   E_terminated total:           0.000000 MeV
#   E_box total:                  0.000000 MeV
#
#                             BALANCE CHECKS
# ----------------------------------------------------------------------
#   N_processed theory:           10000
#   N_processed simulation:       1642
#   N difference:                 8358
#   E_total simulation:           20000.000000 MeV
#   E_processed simulation:       2353.760792 MeV
#   E difference:                 17646.239208 MeV
#
#                            BUILD-UP FACTOR
# ----------------------------------------------------------------------
#   E_out theory:                 1250.000000 MeV
#   B = E_out/E_out_theory:       1.789146
# ======================================================================
